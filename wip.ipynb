# %% [markdown]
# # Import Tensorflow and other libraries

# %%
#!pip install tensorflow
import tensorflow as tf
# Out:
# 2022-11-28 12:36:22.606352: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-28 12:36:22.767264: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-11-28 12:36:22.767531: I tensorflow/compiler/xla/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# ...

# %%
# !pip install opencv-python
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.9/60.9 MB 1.6 MB/s eta 0:00:0000:0100:01m
# ...

# %%
import cv2

# %%
# !ls raw_data/photo/photo1
# Out:
# image0001.jpg  image0311.jpg  image0617.jpg  image0924.jpg  image1407.jpg
# image0002.jpg  image0312.jpg  image0618.jpg  image0925.jpg  image1408.jpg
# image0003.jpg  image0313.jpg  image0619.jpg  image0926.jpg  image1409.jpg
# image0004.jpg  image0314.jpg  image0620.jpg  image0927.jpg  image1410.jpg
# image0005.jpg  image0315.jpg  image0621.jpg  image0928.jpg  image1411.jpg
# image0006.jpg  image0316.jpg  image0622.jpg  image0929.jpg  image1412.jpg
# image0007.jpg  image0317.jpg  image0623.jpg  image0930.jpg  image1413.jpg
# image0008.jpg  image0318.jpg  image0624.jpg  image0931.jpg  image1414.jpg
# image0009.jpg  image0319.jpg  image0625.jpg  image0932.jpg  image1415.jpg
# image0010.jpg  image0320.jpg  image0626.jpg  image0933.jpg  image1416.jpg
# image0011.jpg  image0321.jpg  image0627.jpg  image0934.jpg  image1418.jpg
# image0012.jpg  image0322.jpg  image0628.jpg  image0935.jpg  image1419.jpg
# image0013.jpg  image0323.jpg  image0629.jpg  image0936.jpg  image1420.jpg
# ...

# %%
img1 = cv2.imread('raw_data/photo/photo1/image0001.jpg')

# %%
img1.shape
# Out:
# (250, 250, 3)

# %%
img1
# Out:
# array([[[117, 151,  50],
#         [115, 149,  48],
#         [113, 147,  46],
#         ...,
#         [116, 170,  73],
#         [117, 170,  76],
#         [117, 170,  76]],
#
#        [[122, 156,  55],
#         [120, 154,  53],
#         [118, 152,  51],
#         ...,
#         [122, 176,  79],
#         [120, 173,  79],
#         [120, 173,  79]],
#
#        [[123, 157,  56],
#         [122, 156,  55],
#         [120, 154,  53],
#         ...,
#         [129, 183,  86],
#         [124, 177,  83],
#         [123, 176,  82]],
#
#        ...,
#
#        [[ 47,  66, 101],
#         [ 30,  49,  82],
#         [ 54,  74, 109],
#         ...,
#         [ 38,  56,  79],
#         [ 40,  54,  72],
#         [ 40,  53,  67]],
#
#        [[ 43,  61,  98],
#         [ 47,  66, 101],
#         [ 39,  58,  95],
#         ...,
#         [ 40,  57,  76],
#         [ 37,  50,  64],
#         [ 39,  51,  63]],
#
#        [[ 42,  60,  97],
#         [ 46,  64, 101],
#         [ 36,  55,  92],
# ...

# %%
img2 = cv2.imread('raw_data/photo/photo2/image0001.jpg')
img2.shape
# Out:
# (318, 223, 3)

# %%
img2 = cv2.imread('raw_data/photo/photo3/image0001.jpg')
img2.shape
# Out:
# (340, 475, 3)
